# %% [markdown]
# <a href="https://colab.research.google.com/github/Dee-6777/Analysis-on-Mobile-application-dataset/blob/main/Data_Analysis_on_Mobile_Applications_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset: https://drive.google.com/file/d/1lGIrooUAGjgNSSfD2C9VrS4Oy3paLTdO/view?usp=sharing

# %% [markdown]
# # Importation of Libraries

# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

import re

# %% [markdown]
# # Reading the dataset (Create a DataFrame)

# %%
mobile = pd.read_csv('/content/drive/MyDrive/ShapeAI DST 11021 Oct-Jan Batch 2021-22/Datasets/Mobile_Applications.csv')

# %% [markdown]
# # Data Exploration

# %%
mobile
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                             Parkinson Exercices FR  ...          2.2 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# ...

# %%
mobile.head()
# Out:
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
mobile.tail()
# Out:
#                                                  App  ...         Android Ver
# 10836                               Sya9a Maroc - FR  ...          4.1 and up
# 10837               Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                         Parkinson Exercices FR  ...          2.2 and up
# 10839                  The SCP Foundation DB fr nn5n  ...  Varies with device
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [5 rows x 13 columns]

# %%
mob = mobile.copy()

# %%
mob.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
len(mob.columns)
# Out:
# 13

# %%
mob.shape[1]
# Out:
# 13

# %%
mob.shape
# Out:
# (10841, 13)

# %%
mob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
mob.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
mob.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
mob[mob.Type.isnull()]
# Out:
#                             App  ...         Android Ver
# 9148  Command & Conquer: Rivals  ...  Varies with device
#
# [1 rows x 13 columns]

# %%
mob.head(2)
# Out:
#                                               App  ...   Android Ver
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                             Coloring book moana  ...  4.0.3 and up
#
# [2 rows x 13 columns]

# %%
#  Change the name from "App" -> "App_Name"
mob.rename(columns = {'App': 'App_Name'}, inplace=True)

# %%
mob.columns
# Out:
# Index(['App_Name', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# How many categories are there in the Category column
mob['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
mob['Category'].nunique()
# Out:
# 34

# %%
# Find the maximum and minimum rating
mob.Rating.max()
# Out:
# 19.0

# %%
mob.Rating.min()
# Out:
# 1.0

# %%
# Show all the application whose Rating is 19.0

mob.loc[mob.Rating==mob.Rating.max(),['App_Name','Rating']]
# Out:
#                                       App_Name  Rating
# 10472  Life Made WI-Fi Touchscreen Photo Frame    19.0

# %%
mob.iloc[10472,:]
# Out:
# App_Name                                              NaN
# Category          Life Made WI-Fi Touchscreen Photo Frame
# Rating                                                1.9
# Reviews                                                19
# Size                                                 3.0M
# Installs                                           1,000+
# Type                                                 Free
# Price                                                   0
# Content Rating                                   Everyone
# Genres                                                NaN
# Last Updated                            February 11, 2018
# Current Ver                                        1.0.19
# Android Ver                                    4.0 and up
# Name: 10472, dtype: object

# %%
# Show the applications w.r.t their ratings in the descending order

mob.sort_values(by='Rating', ascending=False)
# Out:
#                                       App_Name  ...   Android Ver
# 10472  Life Made WI-Fi Touchscreen Photo Frame  ...           NaN
# 9511                  Ek Bander Ne Kholi Dukan  ...    4.0 and up
# 10166                     FA Player Essentials  ...  4.0.3 and up
# 7895                Dine In CT - Food Delivery  ...    4.0 and up
# 5118                          Eternal Light AG  ...  4.0.3 and up
# ...                                        ...  ...           ...
# 10824                                Cardio-FR  ...    4.4 and up
# 10825                       Naruto & Boruto FR  ...    4.0 and up
# 10831                 payermonstationnement.fr  ...    4.0 and up
# 10835                                 FR Forms  ...    4.0 and up
# 10838                   Parkinson Exercices FR  ...    2.2 and up
#
# [10841 rows x 13 columns]

# %%
mob.iloc[10472,:] = mob.iloc[10472,:].shift()

# %%
mob.iloc[10472,:]
# Out:
# App_Name                                              NaN
# Category          Life Made WI-Fi Touchscreen Photo Frame
# Rating                                                1.9
# Reviews                                                19
# Size                                                 3.0M
# Installs                                           1,000+
# Type                                                 Free
# Price                                                   0
# Content Rating                                   Everyone
# Genres                                                NaN
# Last Updated                            February 11, 2018
# Current Ver                                        1.0.19
# Android Ver                                    4.0 and up
# Name: 10472, dtype: object

# %%
mob.iloc[10472,0:2] = mob.iloc[10472,0:2].shift()

# %%
mob.iloc[10472]
# Out:
# App_Name                        NaN
# Category                        NaN
# Rating                          1.9
# Reviews                          19
# Size                           3.0M
# Installs                     1,000+
# Type                           Free
# Price                             0
# Content Rating             Everyone
# Genres                          NaN
# Last Updated      February 11, 2018
# Current Ver                  1.0.19
# Android Ver              4.0 and up
# Name: 10472, dtype: object

# %%
mob.iloc[10472,0:1] = "Life Made WI-Fi Touchscreen Photo Frame"

# %%
mob.iloc[10472,:]
# Out:
# App_Name          Life Made WI-Fi Touchscreen Photo Frame
# Category                                              NaN
# Rating                                                1.9
# Reviews                                                19
# Size                                                 3.0M
# Installs                                           1,000+
# Type                                                 Free
# Price                                                   0
# Content Rating                                   Everyone
# Genres                                                NaN
# Last Updated                            February 11, 2018
# Current Ver                                        1.0.19
# Android Ver                                    4.0 and up
# Name: 10472, dtype: object

# %%
mob.iloc[10472,2:3]
# Out:
# Rating    1.9
# Name: 10472, dtype: object

# %%
mob.iloc[10472,2:3] = mob.iloc[10472,2:3].astype('float')

# %%
mob.iloc[10472,2:3] = mob.iloc[10472,2:3].astype('float')

# %%
mob.iloc[10472,2:3]
# Out:
# Rating    1.9
# Name: 10472, dtype: object

# %%
mob.sort_values(by='Rating', ascending=False)
# Out:
#                           App_Name             Category  ... Current Ver Android Ver
# 9056   Santa's Monster Shootout DX                 GAME  ...        1.05  2.2 and up
# 8395                         DG TV   NEWS_AND_MAGAZINES  ...         1.2  4.1 and up
# 8493           PK and DK Audio App               FAMILY  ...       5.1.4  4.1 and up
# 6330     HON. B.J. ACS COLLEGE ALE               FAMILY  ...         3.1  4.3 and up
# 6342                      BJ Foods             BUSINESS  ...         2.7  4.1 and up
# ...                            ...                  ...  ...         ...         ...
# 10824                    Cardio-FR              MEDICAL  ...       2.2.2  4.4 and up
# 10825           Naruto & Boruto FR               SOCIAL  ...         1.0  4.0 and up
# 10831     payermonstationnement.fr  MAPS_AND_NAVIGATION  ...   2.0.148.0  4.0 and up
# 10835                     FR Forms             BUSINESS  ...       1.1.5  4.0 and up
# ...

# %%
mob.head()
# Out:
#                                             App_Name  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
# Find out the Application name where the Category is NaN

mob.loc[mob.Category.isnull(),['App_Name','Category']]
# Out:
#                                       App_Name Category
# 10472  Life Made WI-Fi Touchscreen Photo Frame      NaN

# %%
mob.Category.unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION', nan],
#       dtype=object)

# %%
Life in Hacklife
Made
WI-Fi
Touchscreen
Photo
Frame

# %%
var = mob.iloc[10472][0].upper()

# %%
var = var.split()

# %%
var
# Out:
# ['LIFE', 'MADE', 'WI-FI', 'TOUCHSCREEN', 'PHOTO', 'FRAME']

# %%
arr = []

# %%
for i in var:
  for j,k in zip(mob.App_Name, mob.Category):
    if i in j.upper():
      # print(f'App :{j} AND Category: {k}')
      arr.append(str(k))

# %%
arr
# Out:
# ['COMICS',
#  'DATING',
#  'DATING',
#  'EDUCATION',
#  'EDUCATION',
#  'EDUCATION',
#  'EDUCATION',
#  'EDUCATION',
#  'ENTERTAINMENT',
#  'ENTERTAINMENT',
#  'ENTERTAINMENT',
#  'EVENTS',
#  'EVENTS',
#  'LIBRARIES_AND_DEMO',
#  'GAME',
#  'FAMILY',
#  'FAMILY',
#  'FAMILY',
#  'MEDICAL',
#  'MEDICAL',
#  'SHOPPING',
#  'PRODUCTIVITY',
#  'PARENTING',
#  'FAMILY',
#  'LIFESTYLE',
#  'FAMILY',
#  'FAMILY',
#  'FAMILY',
#  'BOOKS_AND_REFERENCE',
#  'TOOLS',
#  'TOOLS',
#  'FAMILY',
#  'HEALTH_AND_FITNESS',
#  'FAMILY',
#  'TOOLS',
#  'NEWS_AND_MAGAZINES',
#  'FAMILY',
#  'TOOLS',
#  'PRODUCTIVITY',
#  'SOCIAL',
#  'TOOLS',
#  'VIDEO_PLAYERS',
#  'SOCIAL',
#  'GAME',
#  'FAMILY',
#  'NEWS_AND_MAGAZINES',
#  'FAMILY',
#  'FAMILY',
#  'nan',
#  'LIFESTYLE',
#  'FINANCE',
#  'FOOD_AND_DRINK',
#  'MEDICAL',
#  'MEDICAL',
#  'SHOPPING',
#  'SHOPPING',
#  'SHOPPING',
#  'SHOPPING',
#  'SHOPPING',
#  'SHOPPING',
#  'SHOPPING',
#  'SHOPPING',
#  'PARENTING',
#  'SHOPPING',
# ...

# %%
test = pd.DataFrame(arr, columns=['Category'])

# %%
test
# Out:
#             Category
# 0             COMICS
# 1             DATING
# 2             DATING
# 3          EDUCATION
# 4          EDUCATION
# ..               ...
# 304  PERSONALIZATION
# 305      PHOTOGRAPHY
# 306      PHOTOGRAPHY
# 307      PHOTOGRAPHY
# 308              nan
#
# [309 rows x 1 columns]

# %%
test.Category.unique()
# Out:
# array(['COMICS', 'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS',
#        'LIBRARIES_AND_DEMO', 'GAME', 'FAMILY', 'MEDICAL', 'SHOPPING',
#        'PRODUCTIVITY', 'PARENTING', 'LIFESTYLE', 'BOOKS_AND_REFERENCE',
#        'TOOLS', 'HEALTH_AND_FITNESS', 'NEWS_AND_MAGAZINES', 'SOCIAL',
#        'VIDEO_PLAYERS', 'nan', 'FINANCE', 'FOOD_AND_DRINK',
#        'COMMUNICATION', 'PERSONALIZATION', 'ART_AND_DESIGN', 'BEAUTY',
#        'HOUSE_AND_HOME', 'PHOTOGRAPHY'], dtype=object)

# %%
test.Category.value_counts()
# Out:
# PHOTOGRAPHY            155
# TOOLS                   21
# FAMILY                  20
# ART_AND_DESIGN          12
# COMMUNICATION           12
# SHOPPING                11
# VIDEO_PLAYERS            7
# PERSONALIZATION          6
# PRODUCTIVITY             6
# nan                      6
# EDUCATION                5
# EVENTS                   5
# MEDICAL                  5
# SOCIAL                   5
# BEAUTY                   4
# LIFESTYLE                4
# ENTERTAINMENT            3
# BOOKS_AND_REFERENCE      3
# HEALTH_AND_FITNESS       3
# DATING                   3
# PARENTING                3
# COMICS                   2
# GAME                     2
# NEWS_AND_MAGAZINES       2
# FINANCE                  1
# LIBRARIES_AND_DEMO       1
# HOUSE_AND_HOME           1
# FOOD_AND_DRINK           1
# Name: Category, dtype: int64

# %%
mob.iloc[10472,1:2] = 'PHOTOGRAPHY'

# %%
mob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App_Name        10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   object
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: object(13)
# memory usage: 1.1+ MB

# %%
mob.head(2)
# Out:
#                                          App_Name  ...   Android Ver
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                             Coloring book moana  ...  4.0.3 and up
#
# [2 rows x 13 columns]

# %%
mob.Rating.fillna(mob.Rating.mean(), inplace=True)

# %%
mob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App_Name        10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
mob.head(2)
# Out:
#                                          App_Name  ...   Android Ver
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                             Coloring book moana  ...  4.0.3 and up
#
# [2 rows x 13 columns]

# %%
mob.Reviews = mob.Reviews.astype('int')

# %%
mob.head(2)
# Out:
#                                          App_Name  ...   Android Ver
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                             Coloring book moana  ...  4.0.3 and up
#
# [2 rows x 13 columns]

# %%
M -> MB
G -> GB
K -> KB

# %%
for i in mob.Size:
  if 'M' in str(i):
    print('Yes')
# Out:
# Streaming output truncated to the last 5000 lines.
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# ...

# %%
mob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App_Name        10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
mob.head()
# Out:
#                                             App_Name  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
for i in range(len(mob.Size)):
  if bool(re.search('\d', mob.Size[i])):
    mob.Size[i] = re.sub('.$','',str(mob.Size[i]))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
mob.head()
# Out:
#                                             App_Name  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
for i in range(len(mob.Size)):
  if mob.Size[i] == 'Varies with device':
    mob.Size[i] = mob.Size[i].replace('Varies with device','0')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for i in range(len(mob.Size)):
  if mob.Size[i] == 'Varies with device':
    print('Yes')

# %%
mob.Size = mob.Size.astype('float')

# %%
mob.head()
# Out:
#                                             App_Name  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
newdf = mob.copy()

# %%
for i in range(len(newdf.Installs)):
  if '+' in newdf.Installs[i]:
    newdf.Installs[i] = re.sub(',|.$','',newdf.Installs[i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
newdf.Installs = newdf.Installs.astype('int')

# %%
newdf
# Out:
#                                                 App_Name  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                             Parkinson Exercices FR  ...          2.2 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# ...

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App_Name        10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  float64
#  5   Installs        10841 non-null  int64
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
newdf.head()
# Out:
#                                             App_Name  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
newdf.Type.unique()
# Out:
# array(['Free', 'Paid', nan], dtype=object)

# %%
newdf.Type.value_counts()
# Out:
# Free    10040
# Paid      800
# Name: Type, dtype: int64

# %%
newdf.Type = newdf.Type.replace(np.nan,'Free')

# %%
newdf.Type.unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
# 0 -> Free
# 1 -> Paid

newdf.Type = newdf.Type.replace(['Free', 'Paid'],[0,1])

# %%
newdf.Type.unique()
# Out:
# array([0, 1])

# %%
newdf.head()
# Out:
#                                             App_Name  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App_Name        10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  float64
#  5   Installs        10841 non-null  int64
#  6   Type            10841 non-null  int64
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 1.1+ MB

# %%
# App_Name, Type, Price
# newdf.where(newdf.Type==1)
newdf.loc[newdf.Type == 1,['App_Name','Price','Type']]
# Out:
#                                             App_Name   Price  Type
# 234    TurboScan: scan documents and receipts in PDF   $4.99     1
# 235                   Tiny Scanner Pro: PDF Doc Scan   $4.99     1
# 290    TurboScan: scan documents and receipts in PDF   $4.99     1
# 291                   Tiny Scanner Pro: PDF Doc Scan   $4.99     1
# 427                               Puffin Browser Pro   $3.99     1
# ...                                              ...     ...   ...
# 10735                                    FP VoiceBot   $0.99     1
# 10760                                Fast Tract Diet   $7.99     1
# 10782                        Trine 2: Complete Story  $16.99     1
# 10785                                   sugar, sugar   $1.20     1
# 10798                           Word Search Tab 1 FR   $1.04     1
#
# [800 rows x 3 columns]

# %%
for i in range(len(newdf.Price)):
  if '$' in newdf.Price[i]:
    newdf.Price[i] = re.sub('^.','',newdf.Price[i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
newdf.loc[newdf.Type == 1,['App_Name','Price','Type']]
# Out:
#                                             App_Name  Price  Type
# 234    TurboScan: scan documents and receipts in PDF   4.99     1
# 235                   Tiny Scanner Pro: PDF Doc Scan   4.99     1
# 290    TurboScan: scan documents and receipts in PDF   4.99     1
# 291                   Tiny Scanner Pro: PDF Doc Scan   4.99     1
# 427                               Puffin Browser Pro   3.99     1
# ...                                              ...    ...   ...
# 10735                                    FP VoiceBot   0.99     1
# 10760                                Fast Tract Diet   7.99     1
# 10782                        Trine 2: Complete Story  16.99     1
# 10785                                   sugar, sugar   1.20     1
# 10798                           Word Search Tab 1 FR   1.04     1
#
# [800 rows x 3 columns]

# %%
newdf.Price = newdf.Price.astype('float')

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App_Name        10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  float64
#  5   Installs        10841 non-null  int64
#  6   Type            10841 non-null  int64
#  7   Price           10841 non-null  float64
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(3), int64(3), object(7)
# memory usage: 1.1+ MB

# %%
newdf.head()
# Out:
#                                             App_Name  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
newdf['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
newdf['Content Rating'].nunique()
# Out:
# 6

# %%
newdf['Content Rating'].value_counts()
# Out:
# Everyone           8715
# Teen               1208
# Mature 17+          499
# Everyone 10+        414
# Adults only 18+       3
# Unrated               2
# Name: Content Rating, dtype: int64

# %%
newdf['Content Rating'] = newdf['Content Rating'].replace(['Everyone', 'Teen', 'Mature 17+', 'Everyone 10+','Adults only 18+', 'Unrated'],
                                                          [0,1,2,3,4,5])

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App_Name        10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  float64
#  5   Installs        10841 non-null  int64
#  6   Type            10841 non-null  int64
#  7   Price           10841 non-null  float64
#  8   Content Rating  10841 non-null  int64
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 1.1+ MB

# %%
newdf.head()
# Out:
#                                             App_Name  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
newdf[newdf.Genres.isnull()]
# Out:
#                                       App_Name  ... Android Ver
# 10472  Life Made WI-Fi Touchscreen Photo Frame  ...  4.0 and up
#
# [1 rows x 13 columns]
